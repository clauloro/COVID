# %% [markdown]
# # Análisis de datos

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('covid19_tweets.csv')

# %%
df
# Out:
#                      user_name               user_location  \
# 0                       ᏉᎥ☻լꂅϮ                  astroworld
# 1                Tom Basile 🇺🇸                New York, NY
# 2              Time4fisticuffs            Pewee Valley, KY
# 3                  ethel mertz        Stuck in the Middle
# 4                     DIPR-J&K           Jammu and Kashmir
# ...                        ...                         ...
# 179103  AJIMATI AbdulRahman O.             Ilorin, Nigeria
# 179104                   Jason                     Ontario
# 179105             BEEHEMOTH ⏳                   🇨🇦 Canada
# 179106           Gary DelPonte               New York City
# 179107                 TUKY II  Aliwal North, South Africa
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# 2       #Christian #Catholic #Conservative #Reagan #Re...
# 3       #Browns #Indians #ClevelandProud #[]_[] #Cavs ...
# 4       🖊️Official Twitter handle of Department of Inf...
# ...                                                   ...
# 179103    Animal Scientist|| Muslim|| Real Madrid/Chelsea
# 179104  When your cat has more baking soda than Ninja ...
# 179105  ⚒️ The Architects of Free Trade ⚒️ Really Did ...
# 179106  Global UX UI Visual Designer. StoryTeller, Mus...
# 179107  TOKELO SEKHOPA | TUKY II | LAST BORN | EISH TU...
#
#                user_created  user_followers  user_friends  user_favourites  \
# 0       2017-05-26 05:46:42             624           950            18775
# 1       2009-04-16 20:06:23            2253          1677               24
# 2       2009-02-28 18:57:41            9275          9525             7254
# 3       2019-03-07 01:45:06             197           987             1488
# 4       2017-02-12 06:45:15          101009           168              101
# ...                     ...             ...           ...              ...
# 179103  2013-12-30 18:59:19             412          1609             1062
# 179104  2011-12-21 04:41:30             150           182             7295
# 179105  2016-07-13 17:21:59            1623          2160            98000
# 179106  2009-10-27 17:43:13            1338          1111                0
# 179107  2018-04-14 17:30:07              97          1697              566
#
#         user_verified                 date  \
# 0               False  2020-07-25 12:27:21
# 1                True  2020-07-25 12:27:17
# 2               False  2020-07-25 12:27:14
# 3               False  2020-07-25 12:27:10
# 4               False  2020-07-25 12:27:08
# ...               ...                  ...
# 179103          False  2020-08-29 19:44:21
# 179104          False  2020-08-29 19:44:16
# 179105          False  2020-08-29 19:44:15
# 179106          False  2020-08-29 19:44:14
# 179107          False  2020-08-29 19:44:08
#
#                                                      text  \
# 0       If I smelled the scent of hand sanitizers toda...
# 1       Hey @Yankees @YankeesPR and @MLB - wouldn't it...
# 2       @diane3443 @wdunlap @realDonaldTrump Trump nev...
# 3       @brookbanktv The one gift #COVID19 has give me...
# 4       25 July : Media Bulletin on Novel #CoronaVirus...
# ...                                                   ...
# 179103  Thanks @IamOhmai for nominating me for the @WH...
# 179104  2020! The year of insanity! Lol! #COVID19 http...
# 179105  @CTVNews A powerful painting by Juan Lucena. I...
# 179106  More than 1,200 students test positive for #CO...
# 179107  I stop when I see a Stop\n\n@SABCNews\n@Izinda...
#
#                                  hashtags               source  is_retweet
# 0                                     NaN   Twitter for iPhone       False
# 1                                     NaN  Twitter for Android       False
# 2                             ['COVID19']  Twitter for Android       False
# 3                             ['COVID19']   Twitter for iPhone       False
# 4       ['CoronaVirusUpdates', 'COVID19']  Twitter for Android       False
# ...                                   ...                  ...         ...
# 179103                      ['WearAMask']  Twitter for Android       False
# 179104                        ['COVID19']  Twitter for Android       False
# 179105                                NaN      Twitter Web App       False
# 179106                        ['COVID19']   Twitter for iPhone       False
# 179107                                NaN  Twitter for Android       False
#
# [179108 rows x 13 columns]

# %%
df.isna().sum()
# Out:
# user_name               0
# user_location       36771
# user_description    10286
# user_created            0
# user_followers          0
# user_friends            0
# user_favourites         0
# user_verified           0
# date                    0
# text                    0
# hashtags            51334
# source                 77
# is_retweet              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179108 entries, 0 to 179107
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_name         179108 non-null  object
#  1   user_location     142337 non-null  object
#  2   user_description  168822 non-null  object
#  3   user_created      179108 non-null  object
#  4   user_followers    179108 non-null  int64
#  5   user_friends      179108 non-null  int64
#  6   user_favourites   179108 non-null  int64
#  7   user_verified     179108 non-null  bool
#  8   date              179108 non-null  object
#  9   text              179108 non-null  object
#  10  hashtags          127774 non-null  object
#  11  source            179031 non-null  object
#  12  is_retweet        179108 non-null  bool
# dtypes: bool(2), int64(3), object(8)
# memory usage: 15.4+ MB

# %%
df['user_location'].isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 179103    False
# 179104    False
# 179105    False
# 179106    False
# 179107    False
# Name: user_location, Length: 179108, dtype: bool

# %%
df['user_location'].isna().sum()
# Out:
# 36771

# %%
df['user_location'][df['user_location'].isna()]
# Out:
# 7         NaN
# 8         NaN
# 10        NaN
# 16        NaN
# 18        NaN
#          ...
# 179083    NaN
# 179091    NaN
# 179092    NaN
# 179097    NaN
# 179098    NaN
# Name: user_location, Length: 36771, dtype: object

# %%
selected_data = df.loc[20:330, ["user_name","user_location","user_description","user_created"]]
selected_data.head()
# Out:
#             user_name      user_location  \
# 20  The Voice of GenX                NaN
# 21  APO Group English      #AFRICA #MENA
# 22       Micah Pollak  Northwest Indiana
# 23              CAWST     100+ countries
# 24     Florian Bieber               Graz
#
#                                      user_description         user_created
# 20                                                NaN  2011-05-28 15:28:21
# 21  Latest #Africa & #MENA related #News releases ...  2011-02-22 09:09:45
# 22  Associate Professor of Economics (PhD in Econo...  2011-07-22 13:41:42
# 23  Providing training, education and technical co...  2009-08-06 02:43:36
# 24  Niko i ništa, professor, so-called Balkan expe...  2009-06-18 09:46:10

# %%
df.drop(df.dropna().index)
# Out:
#                      user_name               user_location  \
# 0                       ᏉᎥ☻լꂅϮ                  astroworld
# 1                Tom Basile 🇺🇸                New York, NY
# 7               Derbyshire LPC                         NaN
# 8            Prathamesh Bendre                         NaN
# 10      Voice Of CBSE Students                         NaN
# ...                        ...                         ...
# 179096          laura l. sweet             Los Angeles, CA
# 179097               rainmaker                         NaN
# 179098               John Geer                         NaN
# 179105             BEEHEMOTH ⏳                   🇨🇦 Canada
# 179107                 TUKY II  Aliwal North, South Africa
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# 7                                                     NaN
# 8        A poet, reiki practitioner and a student of law.
# 10                                                    NaN
# ...                                                   ...
# 179096  Creative Director/AD/CW, Advertising & Brandin...
# 179097                                                NaN
# 179098  #StayAtHome #StayAtHomeSaveLifes #MaskUp \nFor...
# 179105  ⚒️ The Architects of Free Trade ⚒️ Really Did ...
# 179107  TOKELO SEKHOPA | TUKY II | LAST BORN | EISH TU...
#
#                user_created  user_followers  user_friends  user_favourites  \
# 0       2017-05-26 05:46:42             624           950            18775
# 1       2009-04-16 20:06:23            2253          1677               24
# 7       2012-02-03 18:08:10             608           355               95
# 8       2015-04-25 08:15:41              25            29               18
# 10      2020-07-14 17:50:30               8            10                7
# ...                     ...             ...           ...              ...
# 179096  2008-03-18 16:45:55            2146          1077             5306
# 179097  2017-08-16 22:12:17             709          1158            95006
# 179098  2020-04-18 01:55:14              61           168            10817
# 179105  2016-07-13 17:21:59            1623          2160            98000
# 179107  2018-04-14 17:30:07              97          1697              566
#
#         user_verified                 date  \
# 0               False  2020-07-25 12:27:21
# 1                True  2020-07-25 12:27:17
# 7               False  2020-07-25 12:27:00
# 8               False  2020-07-25 12:26:59
# 10              False  2020-07-25 12:26:53
# ...               ...                  ...
# 179096          False  2020-08-29 19:44:40
# 179097          False  2020-08-29 19:44:35
# 179098          False  2020-08-29 19:44:34
# 179105          False  2020-08-29 19:44:15
# 179107          False  2020-08-29 19:44:08
#
#                                                      text  \
# 0       If I smelled the scent of hand sanitizers toda...
# 1       Hey @Yankees @YankeesPR and @MLB - wouldn't it...
# 7       You now have to wear face coverings when out s...
# 8       Praying for good health and recovery of @Chouh...
# 10      49K+ Covid19 cases still no response from \n@c...
# ...                                                   ...
# 179096  We were really bummed we couldn’t cop one of t...
# 179097  @politvidchannel Just not the lives of #COVID1...
# 179098  Report #COVID19 outbreaks in K-12 schools here...
# 179105  @CTVNews A powerful painting by Juan Lucena. I...
# 179107  I stop when I see a Stop\n\n@SABCNews\n@Izinda...
#
#                                                  hashtags  \
# 0                                                     NaN
# 1                                                     NaN
# 7                                                     NaN
# 8                            ['covid19', 'covidPositive']
# 10                                                    NaN
# ...                                                   ...
# 179096                                                NaN
# 179097           ['COVID19', 'coronavirus', 'TrumpVirus']
# 179098  ['COVID19', 'CloseTheSchools', 'KeepTheSchools...
# 179105                                                NaN
# 179107                                                NaN
#
#                      source  is_retweet
# 0        Twitter for iPhone       False
# 1       Twitter for Android       False
# 7                 TweetDeck       False
# 8       Twitter for Android       False
# 10          Twitter Web App       False
# ...                     ...         ...
# 179096            Instagram       False
# 179097  Twitter for Android       False
# 179098      Twitter Web App       False
# 179105      Twitter Web App       False
# 179107  Twitter for Android       False
#
# [79970 rows x 13 columns]

# %%
df.shape[0] - 79970
# Out:
# 99138

# %%
df_filt = df.dropna().reset_index(drop=True)
df_filt
# Out:
#                     user_name         user_location  \
# 0             Time4fisticuffs      Pewee Valley, KY
# 1                 ethel mertz  Stuck in the Middle
# 2                    DIPR-J&K     Jammu and Kashmir
# 3            🎹 Franz Schubert           Новоро́ссия
# 4                hr bartender       Gainesville, FL
# ...                       ...                   ...
# 99133       New Jersey Herald            Newton, NJ
# 99134                    Pris                  T.O.
# 99135  AJIMATI AbdulRahman O.       Ilorin, Nigeria
# 99136                   Jason               Ontario
# 99137           Gary DelPonte         New York City
#
#                                         user_description         user_created  \
# 0      #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 1      #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 2      🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
# 3      🎼  #Новоро́ссия #Novorossiya #оставайсядома #S...  2018-03-19 16:29:52
# 4      Workplace tips and advice served up in a frien...  2008-08-12 18:19:49
# ...                                                  ...                  ...
# 99133  The New Jersey Herald, a daily newspaper in Ne...  2010-01-07 18:19:37
# 99134  A/V/L Techie, camera op. but twitter has becom...  2008-12-31 16:16:12
# 99135    Animal Scientist|| Muslim|| Real Madrid/Chelsea  2013-12-30 18:59:19
# 99136  When your cat has more baking soda than Ninja ...  2011-12-21 04:41:30
# 99137  Global UX UI Visual Designer. StoryTeller, Mus...  2009-10-27 17:43:13
#
#        user_followers  user_friends  user_favourites  user_verified  \
# 0                9275          9525             7254          False
# 1                 197           987             1488          False
# 2              101009           168              101          False
# 3                1180          1071             1287          False
# 4               79956         54810             3801          False
# ...               ...           ...              ...            ...
# 99133            6274           162               38          False
# 99134             251           160              627          False
# 99135             412          1609             1062          False
# 99136             150           182             7295          False
# 99137            1338          1111                0          False
#
#                       date                                               text  \
# 0      2020-07-25 12:27:14  @diane3443 @wdunlap @realDonaldTrump Trump nev...
# 1      2020-07-25 12:27:10  @brookbanktv The one gift #COVID19 has give me...
# 2      2020-07-25 12:27:08  25 July : Media Bulletin on Novel #CoronaVirus...
# 3      2020-07-25 12:27:06  #coronavirus #covid19 deaths continue to rise....
# 4      2020-07-25 12:27:03  How #COVID19 Will Change Work in General (and ...
# ...                    ...                                                ...
# 99133  2020-08-29 19:44:27  Wallkill school nurse adds COVID-19 monitoring...
# 99134  2020-08-29 19:44:23  we have reached 25mil cases of #covid19, world...
# 99135  2020-08-29 19:44:21  Thanks @IamOhmai for nominating me for the @WH...
# 99136  2020-08-29 19:44:16  2020! The year of insanity! Lol! #COVID19 http...
# 99137  2020-08-29 19:44:14  More than 1,200 students test positive for #CO...
#
#                                               hashtags               source  \
# 0                                          ['COVID19']  Twitter for Android
# 1                                          ['COVID19']   Twitter for iPhone
# 2                    ['CoronaVirusUpdates', 'COVID19']  Twitter for Android
# 3                           ['coronavirus', 'covid19']      Twitter Web App
# 4                            ['COVID19', 'Recruiting']               Buffer
# ...                                                ...                  ...
# 99133  ['nurses', 'COVID19', 'coronavirus', 'schools']       SocialNewsDesk
# 99134                                      ['covid19']      Twitter Web App
# 99135                                    ['WearAMask']  Twitter for Android
# 99136                                      ['COVID19']  Twitter for Android
# 99137                                      ['COVID19']   Twitter for iPhone
#
#        is_retweet
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 99133       False
# 99134       False
# 99135       False
# 99136       False
# 99137       False
#
# [99138 rows x 13 columns]

# %% [markdown]
# # Analisis exploratorio, tratamiento y limpieza de datos

# %%
df_filt.describe()
# Out:
#        user_followers   user_friends  user_favourites
# count    9.913800e+04   99138.000000     9.913800e+04
# mean     1.550841e+05    2374.224334     1.517543e+04
# std      1.012846e+06   10019.923883     4.490681e+04
# min      0.000000e+00       0.000000     0.000000e+00
# 25%      3.220000e+02     210.000000     3.330000e+02
# 50%      1.546000e+03     666.000000     2.184000e+03
# 75%      7.576000e+03    1951.000000     1.038475e+04
# max      2.435916e+07  497363.000000     2.047197e+06

# %%
df_filt.dtypes
# Out:
# user_name           object
# user_location       object
# user_description    object
# user_created        object
# user_followers       int64
# user_friends         int64
# user_favourites      int64
# user_verified         bool
# date                object
# text                object
# hashtags            object
# source              object
# is_retweet            bool
# dtype: object

# %%
df_filt.dtypes[df_filt.dtypes == "object"]
# Out:
# user_name           object
# user_location       object
# user_description    object
# user_created        object
# date                object
# text                object
# hashtags            object
# source              object
# dtype: object

# %%
df_filt['user_name'].value_counts()
# Out:
# covidnews.ch                                    402
# GlobalPandemic.NET                              320
# Blood Donors India                              282
# Hindustan Times                                 267
# IANS Tweets                                     228
#                                                ...
# Julia C. Reinhart                                 1
# Mohammad Y. Al-Bahar (The Diabetic Traveler)      1
# wyoming4paul (I,you,he,she,it,we,you,they)        1
# Mithu Maheswaranathan, MD                         1
# AJIMATI AbdulRahman O.                            1
# Name: user_name, Length: 53239, dtype: int64

# %%
columnas_drop = ["user_name", "user_description"]

# %%
df_filt2 = df_filt.drop(columns = columnas_drop)
print("Tamaño del tablón filtrado: ", df_filt.shape)
print("Tamaño del tablón nuevo: ", df_filt2.shape)
# Out:
# Tamaño del tablón filtrado:  (99138, 13)
# Tamaño del tablón nuevo:  (99138, 11)

# %%
df_filt2.dtypes.value_counts()
# Out:
# object    6
# int64     3
# bool      2
# dtype: int64

# %% [markdown]
# ## Reducción de variables

# %%
df = pd.read_csv('vaccination_all_tweets.csv')

# %%
# Cambia 'tu_columna_objetivo' por la columna objetivo de tu CSV
target = 'user_verified'
features = [x for x in df.columns if x != target]

print(target)
print(features)
# Out:
# user_verified
# ['id', 'user_name', 'user_location', 'user_description', 'user_created', 'user_followers', 'user_friends', 'user_favourites', 'date', 'text', 'hashtags', 'source', 'retweets', 'favorites', 'is_retweet']

# %%
# Asegúrate de seleccionar las columnas numéricas que utilizarás como características
# Si las columnas no son numéricas, tendrás que realizar una conversión o codificación apropiada, como One-Hot Encoding
features = ['user_followers', 'user_friends', 'user_favourites']
target = 'user_verified'

# Rellena los valores faltantes con cero (o cualquier otro valor apropiado)
df[features] = df[features].fillna(0)

# Convierte las columnas de características a tipos numéricos (int64 o float64)
df[features] = df[features].astype('float64')

# Convierte la columna objetivo a un tipo numérico, si es necesario (por ejemplo, si es booleano)
df[target] = df[target].astype('int64')

# %%
arbol_importancia = DecisionTreeRegressor(max_depth=len(features)+10, random_state=42)
arbol_importancia.fit(X=df[features], y=df[target])
# Out:
# DecisionTreeRegressor(max_depth=13, random_state=42)
